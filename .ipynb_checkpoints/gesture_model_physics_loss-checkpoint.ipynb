# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.metrics import classification_report, confusion_matrix

import tensorflow as tf
from keras._tf_keras.keras.models import Sequential, load_model
from keras._tf_keras.keras.layers import Dense, Dropout, BatchNormalization
from keras._tf_keras.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras._tf_keras.keras.losses import sparse_categorical_crossentropy

from keras._tf_keras.keras.optimizers import Adam
from matplotlib.patches import Circle

# %% [markdown]
# ### Constants

# %%
filename="closer_data_coords.csv"
scaler = MinMaxScaler()
model_name = "Gesture_model"
FRAMES = 5
LAMBDA_V = 0.01
LAMBDA_A = 0.01

# %% [markdown]
# ## Data Init and Class Distributions

# %%
filename = "closer_data_coords.csv"
FRAMES = 5

df = pd.read_csv(filename)
df.drop(columns=['source_file', 'source_directory'], inplace=True, errors='ignore')
df.columns = [col.replace('.', '_') for col in df.columns]
df = df.drop(columns=[c for c in df.columns if '_z' in c], errors='ignore')
df.dropna(inplace=True)

# Encode labels
label_encoder = LabelEncoder()
encoded_labels = label_encoder.fit_transform(df['gesture_class'])
num_classes = len(label_encoder.classes_)

def sliding_window(X, y, frames=5):
    xs, ys = [], []
    for i in range(len(X) - frames + 1):
        xs.append(X.iloc[i:i+frames].values)
        ys.append(int(y.iloc[i+frames - 1]))  # ensure scalar labels
    return np.array(xs), np.array(ys)

X_raw = df.drop(columns=['gesture_class']).apply(pd.to_numeric, errors='coerce')
y_raw = pd.Series(encoded_labels)

# %%
print(f"\nNumber of classes: {num_classes}")
print(f"Classes: {label_encoder.classes_}\n")

print(f'data shape: {df.shape}')
print(f'df columns: {df.columns}')
# Out:
# Number of classes: 5
# Classes: ['A-sign' 'B-sign' 'Okay' 'peace_sign' 'thumbs_up']
#
# data shape: (496, 43)
# df columns: Index(['gesture_class', 'WRIST_x', 'WRIST_y', 'THUMB_CMC_x', 'THUMB_CMC_y',
#        'THUMB_MCP_x', 'THUMB_MCP_y', 'THUMB_IP_x', 'THUMB_IP_y', 'THUMB_TIP_x',
#        'THUMB_TIP_y', 'INDEX_FINGER_MCP_x', 'INDEX_FINGER_MCP_y',
#        'INDEX_FINGER_PIP_x', 'INDEX_FINGER_PIP_y', 'INDEX_FINGER_DIP_x',
#        'INDEX_FINGER_DIP_y', 'INDEX_FINGER_TIP_x', 'INDEX_FINGER_TIP_y',
#        'MIDDLE_FINGER_MCP_x', 'MIDDLE_FINGER_MCP_y', 'MIDDLE_FINGER_PIP_x',
#        'MIDDLE_FINGER_PIP_y', 'MIDDLE_FINGER_DIP_x', 'MIDDLE_FINGER_DIP_y',
#        'MIDDLE_FINGER_TIP_x', 'MIDDLE_FINGER_TIP_y', 'RING_FINGER_MCP_x',
#        'RING_FINGER_MCP_y', 'RING_FINGER_PIP_x', 'RING_FINGER_PIP_y',
#        'RING_FINGER_DIP_x', 'RING_FINGER_DIP_y', 'RING_FINGER_TIP_x',
#        'RING_FINGER_TIP_y', 'PINKY_MCP_x', 'PINKY_MCP_y', 'PINKY_PIP_x',
#        'PINKY_PIP_y', 'PINKY_DIP_x', 'PINKY_DIP_y', 'PINKY_TIP_x',
#        'PINKY_TIP_y'],
#       dtype='object')

# %%
def sliding_window(X, y, frames=5):
    xs, ys = [], []

    for i in range(len(X) - frames + 1):
        xs.append(X.iloc[i:i+frames].values)
        ys.append(int(y.iloc[i+frames - 1]))  # ensure scalar labels
    return np.array(xs), np.array(ys)

# %% [markdown]
# ## Data Visualization

# %%
def plot_hand_landmarks(X_raw, y_raw, label_encoder, num_samples=5, frame_idx=0):
    """    
    MediaPipe Hand landmark indices:
    0: Wrist
    1-4: Thumb (CMC, MCP, IP, TIP)
    5-8: Index finger (MCP, PIP, DIP, TIP)
    9-12: Middle finger
    13-16: Ring finger
    17-20: Pinky
    """
    
    # MediaPipe hand connections (which landmarks to connect)
    HAND_CONNECTIONS = [
        # Thumb
        (0, 1), (1, 2), (2, 3), (3, 4),
        # Index finger
        (0, 5), (5, 6), (6, 7), (7, 8),
        # Middle finger
        (0, 9), (9, 10), (10, 11), (11, 12),
        # Ring finger
        (0, 13), (13, 14), (14, 15), (15, 16),
        # Pinky
        (0, 17), (17, 18), (18, 19), (19, 20),
        # Palm
        (5, 9), (9, 13), (13, 17)
    ]
    
    num_gestures = len(label_encoder.classes_)
    fig, axes = plt.subplots(num_gestures, num_samples, 
                             figsize=(3*num_samples, 3*num_gestures))
    
    if num_gestures == 1:
        axes = axes.reshape(1, -1)
    
    # Get feature names and identify x, y coordinates
    feature_names = X_raw.columns.tolist()
    x_features = [f for f in feature_names if '_x' in f]
    y_features = [f for f in feature_names if '_y' in f]
    
    # Ensure we have 21 landmarks (MediaPipe standard)
    num_landmarks = min(len(x_features), len(y_features))
    
    for gesture_idx, gesture_name in enumerate(label_encoder.classes_):
        # Get samples for this gesture
        gesture_mask = y_raw == gesture_idx
        gesture_samples = X_raw[gesture_mask]
        
        # Sample random examples
        sample_indices = np.random.choice(len(gesture_samples), 
                                         min(num_samples, len(gesture_samples)), 
                                         replace=False)
        
        for plot_idx, sample_idx in enumerate(sample_indices):
            ax = axes[gesture_idx, plot_idx] if num_gestures > 1 else axes[plot_idx]
            
            x_coords = gesture_samples.iloc[sample_idx][x_features].values
            y_coords = gesture_samples.iloc[sample_idx][y_features].values
            
            y_coords = -y_coords
            
            for connection in HAND_CONNECTIONS:
                if connection[0] < num_landmarks and connection[1] < num_landmarks:
                    ax.plot([x_coords[connection[0]], x_coords[connection[1]]],
                           [y_coords[connection[0]], y_coords[connection[1]]],
                           'b-', linewidth=2, alpha=0.6)
            
            ax.scatter(x_coords[:num_landmarks], y_coords[:num_landmarks], 
                      c='red', s=50, zorder=5, edgecolors='black', linewidth=1)
            
            ax.scatter(x_coords[0], y_coords[0], 
                      c='green', s=100, zorder=6, edgecolors='black', linewidth=2,
                      marker='s', label='Wrist')
            
            ax.set_xlim(x_coords.min() - 0.05, x_coords.max() + 0.05)
            ax.set_ylim(y_coords.min() - 0.05, y_coords.max() + 0.05)
            ax.set_aspect('equal')
            ax.grid(True, alpha=0.3)
            
            if plot_idx == 0:
                ax.set_ylabel(f'{gesture_name}', fontsize=11, fontweight='bold')
            if gesture_idx == 0:
                ax.set_title(f'Sample {plot_idx + 1}', fontsize=10)
            
            ax.set_xticks([])
            ax.set_yticks([])
    
    plt.suptitle('Hand Landmark Visualization by Gesture Class', 
                 fontsize=14, fontweight='bold', y=1.00)
    plt.tight_layout()
    plt.savefig('hand_shape_visualization.png', dpi=300, bbox_inches='tight')
    plt.show()

# %%
def visualize_neural_network(model, X_sample, layer_names=None):
    # Ensure sample matches model input shape
    input_shape = model.base_model.input_shape  # (batch, ...) or (...,)
    if isinstance(input_shape, tuple):
        expected_features = int(np.prod(input_shape[1:])) if len(input_shape) > 1 else int(np.prod(input_shape))
    else:
        expected_features = None

    # Prepare X_input with proper batch and spatial dims
    X = np.array(X_sample)
    if expected_features is not None and X.size == expected_features:
        # flat vector: reshape to model input (exclude batch dim)
        target_shape = input_shape[1:] if len(input_shape) > 1 else (expected_features,)
        X_input = X.reshape((1,) + target_shape)
    else:
        # try to add batch dim if missing
        if X.ndim == len(input_shape) - 1:
            X_input = X.reshape((1,) + X.shape)
        elif X.ndim == len(input_shape):
            X_input = X
        else:
            # fallback: flatten to 1D and pass as (1, -1)
            X_input = X.reshape(1, -1)

    # Select layers to visualize: prefer Dense layers; for conv layers use channel count
    selected_layers = []
    layer_labels = ['Input\n(Features)']
    for layer in model.base_model.layers:
        # choose Dense and Conv-like layers
        if isinstance(layer, tf.keras.layers.Dense):
            selected_layers.append(layer)
            layer_labels.append(f'{layer.__class__.__name__}\n({layer.units} units)')
        elif isinstance(layer, (tf.keras.layers.Conv1D, tf.keras.layers.Conv2D, tf.keras.layers.Conv3D)):
            channels = int(layer.output_shape[-1])
            selected_layers.append(layer)
            layer_labels.append(f'{layer.__class__.__name__}\n({channels} ch)')

    if not selected_layers:
        raise RuntimeError("No suitable layers found to visualize (no Dense/Conv layers).")

    # Build intermediate model
    intermediate_model = tf.keras.Model(
        inputs=model.base_model.input,
        outputs=[layer.output for layer in selected_layers]
    )

    # Get activations
    activations = intermediate_model.predict(X_input, verbose=0)

    # Convert activations to 2D per-layer vectors (neurons x scalar)
    acts_2d = []
    for act in activations:
        # act shape: (batch, ...) ; reduce spatial dims by mean to get per-channel/neuron scalar
        arr = np.array(act[0])  # remove batch
        if arr.ndim == 0:
            vec = np.array([arr])
        elif arr.ndim == 1:
            vec = arr
        else:
            # collapse spatial dims, keep last dim as "neurons" (channels)
            vec = arr.reshape(-1, arr.shape[-1]).mean(axis=0)
        acts_2d.append(vec)

    # --- PLOTTING (left: architecture, right: heatmap) ---
    fig, axes = plt.subplots(1, 2, figsize=(16, 8))
    ax1, ax2 = axes

    # Layer sizes for layout: input size then each selected layer length
    layer_sizes = [X_input.shape[1] if X_input.ndim == 2 else int(np.prod(X_input.shape[1:]))]
    for v in acts_2d:
        layer_sizes.append(len(v))
    num_layers = len(layer_sizes)
    layer_positions = np.linspace(0, 10, num_layers)
    neuron_positions = []

    for i, (layer_size, x_pos) in enumerate(zip(layer_sizes, layer_positions)):
        y_positions = np.linspace(0, 10, max(1, layer_size))
        neuron_positions.append(y_positions)
        for y_pos in y_positions:
            circle = Circle((x_pos, y_pos), 0.15,
                            color='lightblue' if i == 0 else 'lightcoral' if i == num_layers-1 else 'lightgreen',
                            ec='black', linewidth=1.0, zorder=4)
            ax1.add_patch(circle)

    # Connections (sample)
    for i in range(num_layers - 1):
        src = neuron_positions[i]
        tgt = neuron_positions[i+1]
        num_pairs = len(src) * len(tgt)
        max_connections = 50
        if num_pairs > max_connections:
            idxs = np.random.choice(num_pairs, max_connections, replace=False)
        else:
            idxs = range(num_pairs)
        for conn_idx in idxs:
            s = conn_idx // len(tgt)
            t = conn_idx % len(tgt)
            ax1.plot([layer_positions[i], layer_positions[i+1]], [src[s], tgt[t]],
                     'gray', alpha=0.2, linewidth=0.5, zorder=1)

    for i, (x_pos, label) in enumerate(zip(layer_positions, ['Input'] + layer_labels[1:])):
        ax1.text(x_pos, -1, label, ha='center', fontsize=9, fontweight='bold')

    ax1.set_xlim(-1, 11); ax1.set_ylim(-2, 11); ax1.axis('off'); ax1.set_title('Neural Network Architecture')

    # Heatmap: rows = neuron index, cols = layer index
    max_units = max(len(v) for v in acts_2d)
    activation_matrix = np.zeros((max_units, len(acts_2d)))
    for j, vec in enumerate(acts_2d):
        activation_matrix[:len(vec), j] = vec

    im = ax2.imshow(activation_matrix, cmap='RdYlBu_r', aspect='auto', interpolation='nearest')
    ax2.set_xlabel('Layer Index'); ax2.set_ylabel('Neuron Index')
    ax2.set_title('Forward Pass Activations (Sample Input)')
    plt.colorbar(im, ax=ax2, label='Activation')
    plt.tight_layout()
    plt.savefig('neural_network_visualization.png', dpi=300, bbox_inches='tight')
    plt.show()

# %%
def compute_cost_simple(X, y, w):
    m = len(y)
    predictions = X @ w
    cost = (1 / (2 * m)) * np.sum((predictions - y) ** 2)
    return cost

def compute_gradient_simple(X, y, w):
    m = len(y)
    gradient = (1 / m) * X.T @ (X @ w - y)
    return gradient

def visualize_gradient_descent_1d(X, y, num_iterations=50, learning_rate=0.01):
  
    from sklearn.decomposition import PCA
    
    # Reduce to 1D for visualization
    pca = PCA(n_components=1)
    X_1d = pca.fit_transform(X.reshape(X.shape[0], -1))
    
    # Add bias term
    X_1d_bias = np.c_[np.ones(X_1d.shape[0]), X_1d]
    
    # Initialize
    w = np.random.randn(2, 1) * 0.01
    w_history = [w.copy()]
    cost_history = [compute_cost_simple(X_1d_bias, y.reshape(-1, 1), w)]
    
    # Gradient descent
    for i in range(num_iterations):
        gradient = compute_gradient_simple(X_1d_bias, y.reshape(-1, 1), w)
        w = w - learning_rate * gradient
        w_history.append(w.copy())
        cost_history.append(compute_cost_simple(X_1d_bias, y.reshape(-1, 1), w))
    
    # Create visualization
    fig = plt.figure(figsize=(18, 6))
    
    # --- PLOT 1: Cost vs Iteration ---
    ax1 = plt.subplot(1, 3, 1)
    ax1.plot(cost_history, 'b-', linewidth=2)
    ax1.set_xlabel('Iteration', fontsize=12, fontweight='bold')
    ax1.set_ylabel('Cost J(w)', fontsize=12, fontweight='bold')
    ax1.set_title('Cost vs. Iteration', fontsize=14, fontweight='bold')
    ax1.grid(True, alpha=0.3)
    
    # --- PLOT 2: Cost Function with Gradient Descent Path ---
    ax2 = plt.subplot(1, 3, 2)
    
    # Create cost surface for one parameter (w1, keeping w0 fixed)
    w1_range = np.linspace(w_history[0][1] - 2, w_history[0][1] + 2, 100)
    costs_w1 = []
    
    for w1_val in w1_range:
        w_temp = np.array([[w_history[-1][0]], [w1_val]])
        costs_w1.append(compute_cost_simple(X_1d_bias, y.reshape(-1, 1), w_temp))
    
    # Plot cost curve
    ax2.plot(w1_range, costs_w1, 'b-', linewidth=2, label='J(w)')
    
    # Plot gradient descent path
    w1_path = [w[1, 0] for w in w_history]
    cost_path = cost_history
    
    # Plot arrows showing gradient descent steps
    for i in range(min(15, len(w1_path)-1)):  # Show first 15 steps
        ax2.annotate('', xy=(w1_path[i+1], cost_path[i+1]),
                    xytext=(w1_path[i], cost_path[i]),
                    arrowprops=dict(arrowstyle='->', color='red', lw=2))
    
    # Mark start and end
    ax2.scatter(w1_path[0], cost_path[0], c='green', s=200, 
               marker='o', zorder=5, edgecolors='black', linewidth=2,
               label='Start')
    ax2.scatter(w1_path[-1], cost_path[-1], c='red', s=200,
               marker='*', zorder=5, edgecolors='black', linewidth=2,
               label='Minimum')
    
    ax2.set_xlabel('Parameter w₁', fontsize=12, fontweight='bold')
    ax2.set_ylabel('Cost J(w)', fontsize=12, fontweight='bold')
    ax2.set_title('Gradient Descent on Cost Function', fontsize=14, fontweight='bold')
    ax2.legend(loc='best')
    ax2.grid(True, alpha=0.3)
    
    # --- PLOT 3: Parameter Evolution ---
    ax3 = plt.subplot(1, 3, 3)
    
    w0_path = [w[0, 0] for w in w_history]
    iterations = range(len(w0_path))
    
    ax3_twin = ax3.twinx()
    
    line1 = ax3.plot(iterations, w0_path, 'b-', linewidth=2, label='w₀ (bias)')
    line2 = ax3_twin.plot(iterations, w1_path, 'r-', linewidth=2, label='w₁')
    
    ax3.set_xlabel('Iteration', fontsize=12, fontweight='bold')
    ax3.set_ylabel('w₀ Value', fontsize=12, fontweight='bold', color='b')
    ax3_twin.set_ylabel('w₁ Value', fontsize=12, fontweight='bold', color='r')
    ax3.set_title('Parameter Convergence', fontsize=14, fontweight='bold')
    
    ax3.tick_params(axis='y', labelcolor='b')
    ax3_twin.tick_params(axis='y', labelcolor='r')
    
    # Combined legend
    lines = line1 + line2
    labels = [l.get_label() for l in lines]
    ax3.legend(lines, labels, loc='best')
    
    ax3.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.savefig('gradient_descent_visualization.png', dpi=300, bbox_inches='tight')
    plt.show()
    
    print(f"\nGradient Descent Summary:")
    print(f"Initial cost: {cost_history[0]:.4f}")
    print(f"Final cost: {cost_history[-1]:.4f}")
    print(f"Cost reduction: {((cost_history[0] - cost_history[-1]) / cost_history[0] * 100):.2f}%")
    print(f"Final parameters: w₀={w_history[-1][0,0]:.4f}, w₁={w_history[-1][1,0]:.4f}")

# %% [markdown]
# ## Feature Transforming
#
# basically, reshaping x and y data into 5 frame windows, then splitting and flattening them for neural network and splitting into training, testing, and cross validation sets.

# %%
X_raw = df.drop(columns=['gesture_class']).apply(pd.to_numeric, errors='coerce')
y_raw = pd.Series(encoded_labels)
print(f'xraw shape: {X_raw.shape}, yraw shape: {y_raw.shape}')

X_window, y_window = sliding_window(X_raw, y_raw, frames=5)
print(f'x window shape: {X_window.shape}, y window shape: {y_window.shape}')

X_train, X_, y_train, y_ = train_test_split(
    X_window, y_window, test_size=0.40, random_state=42
)

X_train_flat = X_train.reshape(X_train.shape[0], -1)
X_flat = X_.reshape(X_.shape[0], -1)

X_cv, X_test, y_cv, y_test = train_test_split(
    X_flat, y_, test_size=0.50, random_state=42
)

print(f'X train and test shapes: {X_train.shape, X_test.shape}')

num_features = X_window.shape[2]
num_classes = len(label_encoder.classes_)
# Out:
# xraw shape: (496, 42), yraw shape: (496,)
# x window shape: (492, 5, 42), y window shape: (492,)
# X train and test shapes: ((295, 5, 42), (99, 210))

# %% [markdown]
# so the data looks like this, inputs are 5 frames long and are sliding windows.

# %%
print(X_window[1:3][0:5])
# Out:
# [[[0.64358819 0.34949234 0.57814234 0.33898914 0.52694416 0.29842827
#    0.50666314 0.26098505 0.49360746 0.22840242 0.54624164 0.24674103
#    0.52815413 0.24271192 0.54552531 0.27500027 0.56241721 0.30010429
#    0.57954085 0.23847905 0.55877042 0.23957664 0.57870752 0.2776061
#    0.59616899 0.30669045 0.6144563  0.23473391 0.59015971 0.23949625
#    0.60667551 0.27626082 0.62241888 0.30461383 0.65256733 0.2353542
#    0.62438422 0.23698474 0.63104677 0.26582974 0.64188886 0.2877225 ]
#   [0.55932403 0.29856652 0.50166166 0.29060873 0.45136246 0.25224602
#    0.43217623 0.21479799 0.42500183 0.18392685 0.46809125 0.20762803
#    0.45177799 0.1950877  0.46540883 0.22445618 0.48011816 0.24959075
#    0.50069231 0.19951315 0.48165366 0.18904406 0.49658448 0.22593835
#    0.51096302 0.2560792  0.53567159 0.19466536 0.51178962 0.18918109
#    0.52493536 0.2268752  0.53866464 0.25668862 0.57376254 0.19388168
#    0.54503882 0.18750283 0.5496915  0.21718228 0.56061864 0.24063455]
#   [0.54262376 0.29849446 0.48476449 0.28773624 0.43907213 0.24945365
#    0.42170393 0.21246298 0.41263598 0.18140204 0.45541883 0.20482729
#    0.44004434 0.19182308 0.45212641 0.22083443 0.46676397 0.24712054
#    0.48674721 0.19770344 0.46875578 0.1875729  0.48106924 0.2235335
#    0.49463543 0.25418121 0.5201658  0.19397454 0.49582431 0.18852253
#    0.50725412 0.22491713 0.52101678 0.2548334  0.55661827 0.19438392
#    0.5276134  0.18796737 0.52980447 0.21685007 0.53866249 0.24098203]
#   [0.54967761 0.29810333 0.49017107 0.28577173 0.44512016 0.24704884
#    0.42866319 0.20936343 0.41923693 0.17844406 0.46537861 0.20384881
#    0.44847822 0.18781471 0.45691687 0.21636148 0.46899286 0.2416596
#    0.49672422 0.19793285 0.47623813 0.18572062 0.48820367 0.22158253
#    0.50196111 0.25123477 0.5298366  0.19469225 0.50419039 0.18842682
#    0.51591426 0.22489825 0.52994984 0.25345013 0.56700414 0.19517398
#    0.53532577 0.18808259 0.53889865 0.21684529 0.54972774 0.2396805 ]
#   [0.57652813 0.26601398 0.51961619 0.25536111 0.47369462 0.21483678
#    0.45838726 0.17658168 0.45019299 0.14566934 0.4968057  0.16914698
#    0.4789288  0.15513721 0.48890707 0.18463977 0.50270432 0.21050322
#    0.52844369 0.16423588 0.50534499 0.15207823 0.51634246 0.18818486
#    0.5292719  0.21794115 0.56137908 0.16222307 0.53385037 0.15724634
# ## Input feature Visualization

# %% [markdown]
# ### plotting hand landmarks

# %%
target_names=label_encoder.classes_
print(target_names)
# Out:
# ['A-sign' 'B-sign' 'Okay' 'peace_sign' 'thumbs_up']

# %%
plot_hand_landmarks(X_raw, y_raw, label_encoder, num_samples=5)

# %% [markdown]
# ### Plotting one feature

# %%
frame_idx = 2
feature1_idx = 16
feature2_idx = 17

# Extract features from specific frame
feature1_values = X_window[:, frame_idx, feature1_idx]
feature2_values = X_window[:, frame_idx, feature2_idx]

# %%
feature_names = list(X_raw.columns)
feature1_name = feature_names[feature1_idx]
feature2_name = feature_names[feature2_idx]

# %%
colors = plt.cm.tab10(np.linspace(0, 1, len(label_encoder.classes_)))
fig, ax = plt.subplots(figsize=(12, 10))

for gesture_idx, gesture_name in enumerate(label_encoder.classes_):
    mask = y_window == gesture_idx
    ax.scatter(feature1_values[mask], feature2_values[mask],
                c=[colors[gesture_idx]], 
                label=gesture_name,
                alpha=0.6, 
                s=50,
                edgecolors='black',
                linewidth=0.5)

ax.set_xlabel(f'{feature1_name} (Frame {frame_idx})', fontsize=12, fontweight='bold')
ax.set_ylabel(f'{feature2_name} (Frame {frame_idx})', fontsize=12, fontweight='bold')
ax.set_title(f'Features: {feature1_name} vs {feature2_name}', 
                fontsize=14, fontweight='bold')
ax.legend(loc='best', framealpha=0.9)
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig(f'2d_feature_space_{feature1_name}_{feature2_name}_frame{frame_idx}.png', dpi=300)
plt.show()

# %% [markdown]
# ## Base Neural Network Creation

# %%
base_model = Sequential(
    [
    Dense(64, input_dim=FRAMES*num_features, activation='relu'),
    BatchNormalization(),
    Dropout(0.3),
    Dense(32, activation='relu'),
    BatchNormalization(),
    Dropout(0.3),
    Dense(16, activation='relu'),
    Dropout(0.3),
    Dense(num_classes, activation='softmax')
], name='base_gesture_model')

base_model.summary()
# Out:
# c:\Users\isav3\miniconda3\envs\ml\lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "base_gesture_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_29 (Dense)                │ (None, 64)             │        13,504 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_24          │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_36 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_30 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_25          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_37 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_31 (Dense)                │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_38 (Dropout)            │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_32 (Dense)                │ (None, 5)              │            85 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 16,581 (64.77 KB)
#  Trainable params: 16,389 (64.02 KB)
#  Non-trainable params: 192 (768.00 B)

# %%
w1, b1 = base_model.get_layer('Dense_layer_1').get_weights()

print(f'Initial (randomized) 2 Weights: {w1[:2]}, \nInitial (randomized) 2 Biases: {b1[:2]}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[316], line 1
# ----> 1 w1, b1 = base_model.get_layer('Dense_layer_1').get_weights()
#       3 print(f'Initial (randomized) 2 Weights: {w1[:2]}, \nInitial (randomized) 2 Biases: {b1[:2]}')
#
# File c:\Users\isav3\miniconda3\envs\ml\lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File c:\Users\isav3\miniconda3\envs\ml\lib\site-packages\keras\src\models\model.py:210, in Model.get_layer(self, name, index)
#     208         if layer.name == name:
#     209             return layer
# --> 210     raise ValueError(
#     211         f"No such layer: {name}. Existing layers are: "
#     212         f"{list(layer.name for layer in self.layers)}."
#     213     )
#     214 raise ValueError(
#     215     "Provide either a layer name or layer index at `get_layer`."
#     216 )
#
# ValueError: No such layer: Dense_layer_1. Existing layers are: ['dense_29', 'batch_normalization_24', 'dropout_36', 'dense_30', 'batch_normalization_25', 'dropout_37', 'dense_31', 'dropout_38', 'dense_32'].

# %%
base_model.compile( optimizer=Adam(learning_rate=0.001), loss=tf.keras.losses.SparseCategoricalCrossentropy(), metrics=['accuracy'])

# %% [markdown]
# ## Physics Loss Function Creation

# %% [markdown]
# ### Velocity

# %% [markdown]
# The main idea of a physics loss function to to penalize any jerky or unrealistic movements from the model
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Since our data is already timestepped, take:
#
# **X1 - X0 = velocity**

# %% [markdown]
# If there is a large velocity, thats a jerky motion. **penalize it.**

# %% [markdown]
# ### Acceleration

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Since Acceleration is the difference in velocity, we can write it as:

# %% [markdown]
# ```
# (x2 - x1) = v1,
# (x1 - x0) = v0,
#
# v1 - v0 = (x2 - x1) - (x1 - x0)
# =>
# ```

# %% [markdown]
# **acceleration =  x2 - 2x1 + x0**
#
# If this acceleration is too large, then **penalize it**

# %% [markdown]
# ### Loss Function formulation

# %% [markdown]
# First find the standard loss function from cross entropy

# %% [markdown]
# and add the velocity and acceleration values.

# %%
class PhysicsModel(tf.keras.Model):
    def __init__(self, base_model, time_steps, num_features, lambda_v=0.01, lambda_a=0.01):
        super().__init__()
        self.base_model = base_model
        self.time_steps = time_steps
        self.num_features = num_features
        self.lambda_v = lambda_v
        self.lambda_a = lambda_a
        
    def call(self, inputs):
        return self.base_model(inputs)
    
    def train_step(self, data):
        x, y = data
        
        with tf.GradientTape() as tape:
            y_pred = self(x, training=True)
            
            # basic loss
            ce_loss = tf.keras.losses.sparse_categorical_crossentropy(y, y_pred)
            ce_loss = tf.reduce_mean(ce_loss)
            
            # reshape to (batch, time, features) for physics calculation
            batch_size = tf.shape(x)[0]
            x_reshaped = tf.reshape(x, (batch_size, self.time_steps, self.num_features))
            
            # velocity loss: ||x_t - x_{t-1}||^2
            velocity = x_reshaped[:, 1:, :] - x_reshaped[:, :-1, :]
            velocity_loss = tf.reduce_mean(tf.square(velocity))
            
            # accel loss: ||x_{t+1} - 2*x_t + x_{t-1}||^2
            acceleration = (x_reshaped[:, 2:, :] - 2 * x_reshaped[:, 1:-1, :] + x_reshaped[:, :-2, :])
            acceleration_loss = tf.reduce_mean(tf.square(acceleration))
            
            # total loss
            total_loss = ce_loss + self.lambda_v * velocity_loss + self.lambda_a * acceleration_loss
        
        # update weights
        trainable_vars = self.trainable_variables
        gradients = tape.gradient(total_loss, trainable_vars)
        self.optimizer.apply_gradients(zip(gradients, trainable_vars))
        
        # update metric
        for metric in self.metrics:
            if metric.name == 'loss':
                metric.update_state(total_loss)
            else:
                metric.update_state(y, y_pred)
        
        return {
            "loss": total_loss,
            "ce_loss": ce_loss,
            "velocity_loss": velocity_loss,
            "acceleration_loss": acceleration_loss,
            **{m.name: m.result() for m in self.metrics}
        }
    
    def test_step(self, data):
        x, y = data

        y_pred = self(x, training=False)
        
        ce_loss = tf.keras.losses.sparse_categorical_crossentropy(y, y_pred)
        ce_loss = tf.reduce_mean(ce_loss)
        
        batch_size = tf.shape(x)[0]
        x_reshaped = tf.reshape(x, (batch_size, self.time_steps, self.num_features))
        
        velocity = x_reshaped[:, 1:, :] - x_reshaped[:, :-1, :]
        velocity_loss = tf.reduce_mean(tf.square(velocity))
        
        acceleration = (x_reshaped[:, 2:, :] - 
                      2 * x_reshaped[:, 1:-1, :] + 
                      x_reshaped[:, :-2, :])
        acceleration_loss = tf.reduce_mean(tf.square(acceleration))
        
        total_loss = ce_loss + self.lambda_v * velocity_loss + self.lambda_a * acceleration_loss
        
        for metric in self.metrics:
            if metric.name == 'loss':
                metric.update_state(total_loss)
            else:
                metric.update_state(y, y_pred)
        
        return {
            "loss": total_loss,
            "ce_loss": ce_loss,
            "velocity_loss": velocity_loss,
            "acceleration_loss": acceleration_loss,
            **{m.name: m.result() for m in self.metrics}
        }

# %%
model = PhysicsModel(
    base_model=base_model,
    time_steps=FRAMES,
    num_features=num_features,
    lambda_v=LAMBDA_V,
    lambda_a=LAMBDA_A
)


model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(), 
    metrics=['accuracy']

)
model.summary()
# Out:
# Model: "physics_model_14"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ base_gesture_model (Sequential) │ (None, 5)              │        16,581 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 16,581 (64.77 KB)
#  Trainable params: 16,389 (64.02 KB)
#  Non-trainable params: 192 (768.00 B)

# %%
from matplotlib.patches import Circle
X_sample = X_train_flat[0]  # Use a sample from training data
if X_sample.ndim > 1:
    X_sample = X_sample.flatten()
visualize_neural_network(model, X_sample)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[318], line 5
#       3 if X_sample.ndim > 1:
#       4     X_sample = X_sample.flatten()
# ----> 5 visualize_neural_network(model, X_sample)
#
# Cell In[306], line 43, in visualize_neural_network(model, X_sample, layer_names)
#      39     raise RuntimeError("No suitable layers found to visualize (no Dense/Conv layers).")
#      41 # Build intermediate model
#      42 intermediate_model = tf.keras.Model(
# ---> 43     inputs=model.base_model.input,
#      44     outputs=[layer.output for layer in selected_layers]
#      45 )
#      47 # Get activations
#      48 activations = intermediate_model.predict(X_input, verbose=0)
#
# File c:\Users\isav3\miniconda3\envs\ml\lib\site-packages\keras\src\ops\operation.py:275, in Operation.input(self)
#     265 @property
#     266 def input(self):
#     267     """Retrieves the input tensor(s) of a symbolic operation.
#     268
#     269     Only returns the tensor(s) corresponding to the *first time*
#    (...)
#     273         Input tensor or list of input tensors.
#     274     """
# --> 275     return self._get_node_attribute_at_index(0, "input_tensors", "input")
#
# File c:\Users\isav3\miniconda3\envs\ml\lib\site-packages\keras\src\ops\operation.py:306, in Operation._get_node_attribute_at_index(self, node_index, attr, attr_name)
#     290 """Private utility to retrieves an attribute (e.g. inputs) from a node.
#     291
#     292 This is used to implement the properties:
#    (...)
#     303     The operation's attribute `attr` at the node of index `node_index`.
#     304 """
#     305 if not self._inbound_nodes:
# --> 306     raise AttributeError(
#     307         f"The layer {self.name} has never been called "
#     308         f"and thus has no defined {attr_name}."
#     309     )
#     310 if not len(self._inbound_nodes) > node_index:
#     311     raise ValueError(
#     312         f"Asked to get {attr_name} at node "
#     313         f"{node_index}, but the operation has only "
#     314         f"{len(self._inbound_nodes)} inbound nodes."
#     315     )
#
# AttributeError: The layer base_gesture_model has never been called and thus has no defined input.

# %%
X_flat = X_window.reshape(X_window.shape[0], -1)
if y_window.ndim > 1:
    y_plot = y_window.flatten()
else:
    y_plot = y_window

visualize_gradient_descent_1d(
    X_flat,
    y_plot,
    num_iterations=100,
    learning_rate=0.01
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[219], line 3
#       1 X_flat = X_window.reshape(X_window.shape[0], -1)
# ----> 3 visualize_gradient_descent_1d(X_window, y_window,
#       4                                 num_iterations=100,
#       5                                 learning_rate=0.01)
#
# Cell In[210], line 60, in visualize_gradient_descent_1d(X, y, num_iterations, learning_rate)
#      58 for w1_val in w1_range:
#      59     w_temp = np.array([[w_history[-1][0]], [w1_val]])
# ---> 60     costs_w1.append(compute_cost_simple(X_1d_bias, y.reshape(-1, 1), w_temp))
#      62 # Plot cost curve
#      63 ax2.plot(w1_range, costs_w1, 'b-', linewidth=2, label='J(w)')
#
# Cell In[210], line 4, in compute_cost_simple(X, y, w)
#       2 """Simple cost function for 1 parameter (for visualization)"""
#       3 m = len(y)
# ----> 4 predictions = X @ w
#       5 cost = (1 / (2 * m)) * np.sum((predictions - y) ** 2)
#       6 return cost
#
# ValueError: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 1 is different from 2)

# %%
early_stopping = EarlyStopping(monitor='val_accuracy', patience=15, mode='max', restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, verbose=1)

# Ensure train/test inputs are flattened and shape-compatible
if X_train_flat.ndim != 2:
    X_train_flat = X_train_flat.reshape(X_train_flat.shape[0], -1)
if X_test.ndim != 2:
    X_test = X_test.reshape(X_test.shape[0], -1)

history = model.fit(
    X_train_flat, y_train,
    epochs=100,
    batch_size=32,
    validation_data=(X_test, y_test),
    callbacks=[early_stopping, reduce_lr],
    verbose=1
)

print("\nModel architecture:")
model.summary()
# Out:
# Epoch 1/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - acceleration_loss: 0.0017 - ce_loss: 2.0727 - accuracy: 0.2727 - loss: 2.0082 - velocity_loss: 0.0010 - val_acceleration_loss: 9.1345e-04 - val_ce_loss: 1.5243 - val_loss: 1.5385 - val_velocity_loss: 0.0013 - learning_rate: 0.0010
# Epoch 2/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - acceleration_loss: 0.0174 - ce_loss: 1.2654 - accuracy: 0.3030 - loss: 1.6969 - velocity_loss: 0.0107 - val_acceleration_loss: 9.1345e-04 - val_ce_loss: 1.5066 - val_loss: 1.5231 - val_velocity_loss: 0.0013 - learning_rate: 0.0010
# Epoch 3/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - acceleration_loss: 0.0689 - ce_loss: 1.8843 - accuracy: 0.3131 - loss: 1.5895 - velocity_loss: 0.0215 - val_acceleration_loss: 9.1345e-04 - val_ce_loss: 1.4959 - val_loss: 1.5086 - val_velocity_loss: 0.0013 - learning_rate: 0.0010
# Epoch 4/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - acceleration_loss: 0.0542 - ce_loss: 1.2547 - accuracy: 0.3737 - loss: 1.2952 - velocity_loss: 0.0182 - val_acceleration_loss: 9.1345e-04 - val_ce_loss: 1.4201 - val_loss: 1.4591 - val_velocity_loss: 0.0013 - learning_rate: 0.0010
# c:\Users\isav3\miniconda3\envs\ml\lib\site-packages\keras\src\callbacks\early_stopping.py:99: UserWarning: Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: acceleration_loss,ce_loss,accuracy,loss,val_acceleration_loss,val_ce_loss,val_loss,val_velocity_loss,velocity_loss
#   current = self.get_monitor_value(logs)
# Epoch 5/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - acceleration_loss: 9.5559e-04 - ce_loss: 1.4583 - accuracy: 0.3131 - loss: 1.2904 - velocity_loss: 7.1571e-04 - val_acceleration_loss: 9.1345e-04 - val_ce_loss: 1.3950 - val_loss: 1.4393 - val_velocity_loss: 0.0013 - learning_rate: 0.0010
# Epoch 6/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - acceleration_loss: 0.0028 - ce_loss: 1.0046 - accuracy: 0.2727 - loss: 1.1850 - velocity_loss: 0.0022 - val_acceleration_loss: 9.1345e-04 - val_ce_loss: 1.3904 - val_loss: 1.4410 - val_velocity_loss: 0.0013 - learning_rate: 0.0010
# Epoch 7/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - acceleration_loss: 0.0017 - ce_loss: 0.6841 - accuracy: 0.3333 - loss: 1.1343 - velocity_loss: 0.0014 - val_acceleration_loss: 9.1345e-04 - val_ce_loss: 1.4018 - val_loss: 1.4338 - val_velocity_loss: 0.0013 - learning_rate: 0.0010
# Epoch 8/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - acceleration_loss: 0.0188 - ce_loss: 1.6265 - accuracy: 0.4444 - loss: 1.0890 - velocity_loss: 0.0098 - val_acceleration_loss: 9.1345e-04 - val_ce_loss: 1.3728 - val_loss: 1.4095 - val_velocity_loss: 0.0013 - learning_rate: 0.0010
# Epoch 9/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - acceleration_loss: 0.0017 - ce_loss: 1.0289 - accuracy: 0.4242 - loss: 0.9788 - velocity_loss: 0.0010 - val_acceleration_loss: 9.1345e-04 - val_ce_loss: 1.2433 - val_loss: 1.3556 - val_velocity_loss: 0.0013 - learning_rate: 0.0010
# Epoch 10/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - acceleration_loss: 0.0781 - ce_loss: 1.1861 - accuracy: 0.3838 - loss: 0.9176 - velocity_loss: 0.0365 - val_acceleration_loss: 9.1345e-04 - val_ce_loss: 1.1849 - val_loss: 1.3338 - val_velocity_loss: 0.0013 - learning_rate: 0.0010
# Epoch 11/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - acceleration_loss: 0.0147 - ce_loss: 1.7004 - accuracy: 0.4747 - loss: 0.9643 - velocity_loss: 0.0109 - val_acceleration_loss: 9.1345e-04 - val_ce_loss: 1.2432 - val_loss: 1.3332 - val_velocity_loss: 0.0013 - learning_rate: 0.0010
# Epoch 12/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - acceleration_loss: 3.9293e-04 - ce_loss: 0.6803 - accuracy: 0.4444 - loss: 0.9037 - velocity_loss: 0.0010 - val_acceleration_loss: 9.1345e-04 - val_ce_loss: 1.5263 - val_loss: 1.4649 - val_velocity_loss: 0.0013 - learning_rate: 0.0010
# Epoch 13/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - acceleration_loss: 0.0015 - ce_loss: 0.5702 - accuracy: 0.4040 - loss: 0.8082 - velocity_loss: 0.0011 - val_acceleration_loss: 9.1345e-04 - val_ce_loss: 1.5533 - val_loss: 1.4778 - val_velocity_loss: 0.0013 - learning_rate: 0.0010
# Epoch 14/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - acceleration_loss: 0.0032 - ce_loss: 0.3573 - accuracy: 0.4040 - loss: 0.7621 - velocity_loss: 0.0026 - val_acceleration_loss: 9.1345e-04 - val_ce_loss: 1.4194 - val_loss: 1.4048 - val_velocity_loss: 0.0013 - learning_rate: 0.0010
# Epoch 15/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - acceleration_loss: 0.1230 - ce_loss: 0.7180 - accuracy: 0.4545 - loss: 0.7266 - velocity_loss: 0.0323 - val_acceleration_loss: 9.1345e-04 - val_ce_loss: 1.2999 - val_loss: 1.3321 - val_velocity_loss: 0.0013 - learning_rate: 0.0010
# Epoch 16/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - acceleration_loss: 0.
#  1/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - acceleration_loss: 0.0067 - ce_loss: 0.6852 - accuracy: 0.8438 - loss: 0.6853 - velocity_loss: 0.0042
# Epoch 99: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - acceleration_loss: 0.1494 - ce_loss: 0.2631 - accuracy: 0.9495 - loss: 0.2700 - velocity_loss: 0.0580 - val_acceleration_loss: 9.1345e-04 - val_ce_loss: 0.0046 - val_loss: 0.1199 - val_velocity_loss: 0.0013 - learning_rate: 1.9531e-06
# Epoch 100/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - acceleration_loss: 0.0314 - ce_loss: 1.4705 - accuracy: 0.9596 - loss: 0.3807 - velocity_loss: 0.0175 - val_acceleration_loss: 9.1345e-04 - val_ce_loss: 0.0046 - val_loss: 0.1195 - val_velocity_loss: 0.0013 - learning_rate: 9.7656e-07
#
# Model architecture:
# Model: "physics_model_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ base_gesture_model (Sequential) │ (None, 5)              │        16,581 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 49,361 (192.82 KB)
#  Trainable params: 16,389 (64.02 KB)
#  Non-trainable params: 192 (768.00 B)
#  Optimizer params: 32,780 (128.05 KB)

# %%
print('Updated weights and biases:')
w2, b2, = base_model.get_layer('Dense_layer_1').get_weights()
print(f'Weights: {w2}\nBiases: {b2}')
# Out:
# Updated weights and biases:
# Weights: [[ 0.03337935  0.11839827  0.04843548 ... -0.07706434 -0.1320837
#   -0.0112819 ]
#  [ 0.11737361 -0.11289193 -0.01291875 ... -0.08835657 -0.0270786
#   -0.14662732]
#  [-0.14875185  0.08856828 -0.08531786 ...  0.127733    0.04413568
#   -0.14665848]
#  ...
#  [-0.01505993  0.02234535 -0.01176129 ... -0.0054449   0.03704406
#    0.00960014]
#  [ 0.11429769 -0.06464113  0.1648108  ... -0.14348419 -0.05073059
#   -0.04703786]
#  [-0.17413345  0.06209514  0.10825885 ... -0.00447144 -0.00421989
#   -0.14855053]]
# Biases: [ 0.02428292 -0.00642905  0.02927843  0.01787287 -0.00352724  0.
#   0.00225182  0.00358925  0.02889144  0.         -0.0042098   0.03563758
#   0.01365777  0.01584491  0.0760553  -0.00570426 -0.00467835 -0.00660939
#  -0.02631068  0.06451844 -0.00324306  0.          0.01829669 -0.00600526
#  -0.00712293  0.         -0.00727773 -0.01177338  0.06412118  0.01239804
#  -0.00582737  0.01215835  0.          0.00788058  0.         -0.00600533
#  -0.00669653 -0.00756061  0.00728696  0.00954837 -0.00600529  0.
#   0.         -0.00473076 -0.00542003 -0.00803593  0.01353867 -0.01538763
#   0.0095454  -0.00522867  0.          0.          0.05088072 -0.00211932
#   0.         -0.01036366  0.02720069 -0.00796792  0.02020878 -0.01157215
#   0.         -0.01182515 -0.00705445 -0.00708513]

# %%
print('Updated weights and biases:')
w2, b2, = base_model.get_layer('Dense_layer_1').get_weights()
print(f'Weights: {w2}\nBiases: {b2}')

# Evaluate on cross-validation set
print("\nEvaluating on Cross-Validation Set:")
cv_results = model.evaluate(X_cv, y_cv, verbose=1)
print(f"CV Loss: {cv_results[0]}, CV Accuracy: {cv_results[1]}")

y_pred_cv = np.argmax(model.predict(X_cv), axis=1)
print("CV Classification Report:")
print(classification_report(y_cv, y_pred_cv, target_names=label_encoder.classes_))
# Out:
# Updated weights and biases:
# Weights: [[ 0.03337935  0.11839827  0.04843548 ... -0.07706434 -0.1320837
#   -0.0112819 ]
#  [ 0.11737361 -0.11289193 -0.01291875 ... -0.08835657 -0.0270786
#   -0.14662732]
#  [-0.14875185  0.08856828 -0.08531786 ...  0.127733    0.04413568
#   -0.14665848]
#  ...
#  [-0.01505993  0.02234535 -0.01176129 ... -0.0054449   0.03704406
#    0.00960014]
#  [ 0.11429769 -0.06464113  0.1648108  ... -0.14348419 -0.05073059
#   -0.04703786]
#  [-0.17413345  0.06209514  0.10825885 ... -0.00447144 -0.00421989
#   -0.14855053]]
# Biases: [ 0.02428292 -0.00642905  0.02927843  0.01787287 -0.00352724  0.
#   0.00225182  0.00358925  0.02889144  0.         -0.0042098   0.03563758
#   0.01365777  0.01584491  0.0760553  -0.00570426 -0.00467835 -0.00660939
#  -0.02631068  0.06451844 -0.00324306  0.          0.01829669 -0.00600526
#  -0.00712293  0.         -0.00727773 -0.01177338  0.06412118  0.01239804
#  -0.00582737  0.01215835  0.          0.00788058  0.         -0.00600533
#  -0.00669653 -0.00756061  0.00728696  0.00954837 -0.00600529  0.
#   0.         -0.00473076 -0.00542003 -0.00803593  0.01353867 -0.01538763
#   0.0095454  -0.00522867  0.          0.          0.05088072 -0.00211932
#   0.         -0.01036366  0.02720069 -0.00796792  0.02020878 -0.01157215
#   0.         -0.01182515 -0.00705445 -0.00708513]
#
# Evaluating on Cross-Validation Set:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - acceleration_loss: 0.0670 - ce_loss: 0.1139 - accuracy: 0.9796 - loss: 0.1081 - velocity_loss: 0.0321
# CV Loss: 0.10810668766498566, CV Accuracy: 0.06698379665613174
# WARNING:tensorflow:5 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000024FDCD04A60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/stepWARNING:tensorflow:6 out of the last 12 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000024FDCD04A60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# CV Classification Report:
#               precision    recall  f1-score   support
#
#       A-sign       1.00      1.00      1.00        18
#       B-sign       0.95      1.00      0.98        20
#         Okay       1.00      0.87      0.93        15
#   peace_sign       1.00      1.00      1.00        20
#    thumbs_up       0.96      1.00      0.98        25
#
#     accuracy                           0.98        98
#    macro avg       0.98      0.97      0.98        98
# weighted avg       0.98      0.98      0.98        98

# %%
# Incomplete cell removed

# %% [markdown]
# ## Model Prediction

# %%
y_pred = np.argmax(model.predict(X_test), axis=1)

print("CLASSIFICATION REPORT")
print(classification_report(y_test, y_pred, target_names=label_encoder.classes_))

#save it
save_dir = 'Trained-Models'
os.makedirs(save_dir, exist_ok=True)
model.base_model.save(os.path.join(save_dir, f'{model_name}.keras'))
print(f"saved as {os.path.join(save_dir, model_name + '.keras')}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# CLASSIFICATION REPORT
#               precision    recall  f1-score   support
#
#       A-sign       1.00      0.87      0.93        30
#       B-sign       1.00      1.00      1.00        17
#         Okay       1.00      1.00      1.00        18
#   peace_sign       0.73      1.00      0.85        11
#    thumbs_up       1.00      1.00      1.00        23
#
#     accuracy                           0.96        99
#    macro avg       0.95      0.97      0.95        99
# weighted avg       0.97      0.96      0.96        99
#
# saved as Trained-Models\Gesture_model.keras

# %% [markdown]
# ## Model Visualization

# %% [markdown]
# ### Confusion Matrices:
# normalized and non-normalized cms

# %%
cm = confusion_matrix(y_test, y_pred)

# Confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Reds',
            xticklabels=label_encoder.classes_,
            yticklabels=label_encoder.classes_)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.tight_layout()

save_dir = 'Trained-Models'
os.makedirs(save_dir, exist_ok=True)
plt.savefig(os.path.join(save_dir, f'{model_name}_confusion_matrix.png'))
plt.show()
